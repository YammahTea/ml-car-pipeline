# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from category_encoders import TargetEncoder
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Phase 1: Initial Data Exploration

# %% [markdown]
# ##### 1-Load data
#
# ##### 2-See info
#
# ##### 3-Look at the first few rows
#
# ##### 4-Basic statistics

# %%
df = pd.read_csv('../data/car_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  object
#  2   Customer Name  23905 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.9+ MB

# %%
df.head()
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  1/2/2022     Geraldine   Male          13500
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
# 2  C_CND_000003  1/2/2022        Gianna   Male        1035000
# 3  C_CND_000004  1/2/2022       Giselle   Male          13500
# 4  C_CND_000005  1/2/2022         Grace   Male        1465000
#
#                            Dealer_Name   Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                       Engine Transmission       Color  Price ($)  Dealer_No   \
# 0  DoubleÂ Overhead Camshaft         Auto       Black      26000  06457-3834
# 1  DoubleÂ Overhead Camshaft         Auto       Black      19000  60504-7114
# 2          Overhead Camshaft       Manual         Red      31500  38701-8047
# 3          Overhead Camshaft       Manual  Pale White      14000  99301-3882
# 4  DoubleÂ Overhead Camshaft         Auto         Red      24500  53546-9427
#
#   Body Style    Phone Dealer_Region
# 0        SUV  8264678    Middletown
# 1        SUV  6848189        Aurora
# 2  Passenger  7298798    Greenville
# 3        SUV  6257557         Pasco
# 4  Hatchback  7081483    Janesville

# %%
df.describe()
# Out:
#        Annual Income     Price ($)         Phone
# count   2.390600e+04  23906.000000  2.390600e+04
# mean    8.308403e+05  28090.247846  7.497741e+06
# std     7.200064e+05  14788.687608  8.674920e+05
# min     1.008000e+04   1200.000000  6.000101e+06
# 25%     3.860000e+05  18001.000000  6.746495e+06
# 50%     7.350000e+05  23000.000000  7.496198e+06
# 75%     1.175750e+06  34000.000000  8.248146e+06
# max     1.120000e+07  85800.000000  8.999579e+06

# %% [markdown]
# ## Phase 2: Data Quality Issues

# %% [markdown]
# ##### 1-Handel missing values

# %%
df.isnull().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    1
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %%
print(df.isnull().sum()/df.count())
# Out:
# Car_id           0.000000
# Date             0.000000
# Customer Name    0.000042
# Gender           0.000000
# Annual Income    0.000000
# Dealer_Name      0.000000
# Company          0.000000
# Model            0.000000
# Engine           0.000000
# Transmission     0.000000
# Color            0.000000
# Price ($)        0.000000
# Dealer_No        0.000000
# Body Style       0.000000
# Phone            0.000000
# Dealer_Region    0.000000
# dtype: float64

# %% [markdown]
# Note: only one null value in Customer Name (lower than 5%  of our data), wont affect our data

# %%
df = df.dropna(axis=0, how='any')
df.isnull().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    0
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %% [markdown]
# ##### 2-Handel duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### 3-Fix data types

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Phone'] = df['Phone'].astype('string')

# %% [markdown]
# ##### 4-Fix typos in Engine column

# %%
df['Engine'].value_counts()
# Out:
# Engine
# DoubleÂ Overhead Camshaft    12570
# Overhead Camshaft            11335
# Name: count, dtype: int64

# %%
df.replace({'Â ': ' '}, regex=True, inplace=True)

# %%
df['Engine'].value_counts()
# Out:
# Engine
# Double Overhead Camshaft    12570
# Overhead Camshaft           11335
# Name: count, dtype: int64

# %% [markdown]
# ## Phase 3: Outlier Detection & Removal

# %% [markdown]
# #### 1-Remove price outliers within groups

# %% [markdown]
# After careful examination in the data, I have noticed that the price for the same car (same dealer_region, same color, same model, almost the same income annual for the customer) varies, for example:

# %% [markdown]
# 1- MiddleTown | Corolla | Pale White | 20000
# 2- MiddleTown | Corolla | Pale White | 45000

# %% [markdown]
# Which means we have price outliers with the same group, so I decided to remove them via IQR

# %%
def remove_price_outliers(df):

    grouping_cols = ['Company', 'Model', 'Color', 'Dealer_Region']

    # Calculate IQR for each group
    def flag_outliers(group):
        Q1 = group['Price ($)'].quantile(0.25)
        Q3 = group['Price ($)'].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 *    IQR

        # Flag rows with True/False if they are an outlier
        # True -> no outlier || False -> outlier
        group['is_valid'] = (group['Price ($)'] >= lower_bound) & (group['Price ($)'] <= upper_bound)
        return group

    # Apply to each group
    df = df.groupby(grouping_cols, group_keys=False).apply(flag_outliers)

    # Show how many outliers were found
    # The ~ is the "NOT" operator for pandas, using not won't work and will give an error
    print(f"Found {(~df['is_valid']).sum()} outliers out of {len(df)} rows")
    print(f"That's {(~df['is_valid']).sum() / len(df) * 100:.2f}% of data")

    # Keep only valid rows
    df_clean = df[df['is_valid']].drop('is_valid', axis=1).copy()

    return df_clean


df_clean = remove_price_outliers(df)
# Out:
# Found 1825 outliers out of 23905 rows
# That's 7.63% of data

# %%
df_clean
# Out:
#              Car_id       Date Customer Name  Gender  Annual Income  \
# 0      C_CND_000001 2022-01-02     Geraldine    Male          13500
# 1      C_CND_000002 2022-01-02           Gia    Male        1480000
# 2      C_CND_000003 2022-01-02        Gianna    Male        1035000
# 3      C_CND_000004 2022-01-02       Giselle    Male          13500
# 4      C_CND_000005 2022-01-02         Grace    Male        1465000
# ...             ...        ...           ...     ...            ...
# 23901  C_CND_023902 2023-12-31        Martin    Male          13500
# 23902  C_CND_023903 2023-12-31         Jimmy  Female         900000
# 23903  C_CND_023904 2023-12-31          Emma    Male         705000
# 23904  C_CND_023905 2023-12-31      Victoire    Male          13500
# 23905  C_CND_023906 2023-12-31       Donovan    Male        1225000
#
#                                Dealer_Name    Company       Model  \
# 0      Buddy Storbeck's Diesel Service Inc       Ford  Expedition
# 1                         C & M Motors Inc      Dodge     Durango
# 2                              Capitol KIA   Cadillac    Eldorado
# 3                   Chrysler of Tri-Cities     Toyota      Celica
# 4                        Chrysler Plymouth      Acura          TL
# ...                                    ...        ...         ...
# 23901                     C & M Motors Inc   Plymouth     Voyager
# 23902       Ryder Truck Rental and Leasing  Chevrolet       Prizm
# 23903               Chrysler of Tri-Cities        BMW        328i
# 23904                    Chrysler Plymouth  Chevrolet       Metro
# 23905                      Pars Auto Sales      Lexus       ES300
#
#                          Engine Transmission       Color  Price ($)  \
# 0      Double Overhead Camshaft         Auto       Black      26000
# 1      Double Overhead Camshaft         Auto       Black      19000
# 2             Overhead Camshaft       Manual         Red      31500
# 3             Overhead Camshaft       Manual  Pale White      14000
# 4      Double Overhead Camshaft         Auto         Red      24500
# ...                         ...          ...         ...        ...
# 23901         Overhead Camshaft       Manual         Red      12000
# 23902  Double Overhead Camshaft         Auto       Black      16000
# 23903         Overhead Camshaft       Manual         Red      21000
# 23904  Double Overhead Camshaft         Auto       Black      31000
# 23905  Double Overhead Camshaft         Auto  Pale White      27500
#
#        Dealer_No  Body Style    Phone Dealer_Region
# 0      06457-3834        SUV  8264678    Middletown
# 1      60504-7114        SUV  6848189        Aurora
# 2      38701-8047  Passenger  7298798    Greenville
# 3      99301-3882        SUV  6257557         Pasco
# 4      53546-9427  Hatchback  7081483    Janesville
# ...           ...        ...      ...           ...
# 23901  60504-7114  Passenger  8583598         Pasco
# 23902  06457-3834    Hardtop  7914229    Middletown
# 23903  99301-3882      Sedan  7659127    Scottsdale
# 23904  53546-9427  Passenger  6030764        Austin
# 23905  38701-8047    Hardtop  7020564    Middletown
#
# [22080 rows x 16 columns]

# %% [markdown]
# #### 2-Check outliers in other numerical columns

# %% [markdown]
# Note: Only Annual Income will be checked

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22080 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         22080 non-null  object
#  1   Date           22080 non-null  datetime64[ns]
#  2   Customer Name  22080 non-null  object
#  3   Gender         22080 non-null  object
#  4   Annual Income  22080 non-null  int64
#  5   Dealer_Name    22080 non-null  object
#  6   Company        22080 non-null  object
#  7   Model          22080 non-null  object
#  8   Engine         22080 non-null  object
#  9   Transmission   22080 non-null  object
#  10  Color          22080 non-null  object
#  11  Price ($)      22080 non-null  int64
#  12  Dealer_No      22080 non-null  object
#  13  Body Style     22080 non-null  object
#  14  Phone          22080 non-null  string
#  15  Dealer_Region  22080 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(12), string(1)
# memory usage: 2.9+ MB

# %%
plt.figure(figsize=(8,8))
plt.boxplot(df_clean['Annual Income'])
ax = plt.gca()  # Get current axes
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda num, p: f'{int(num):,}')) #Just to fix the numbers from having "1e7" to display the bigger picture of that number
plt.show()

# %%
print(f"Before: {len(df_clean)}")

Q1 = df_clean['Annual Income'].quantile(0.25)
Q3 = df_clean['Annual Income'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df_clean = df_clean[(df_clean['Annual Income'] >= lower_bound) & (df_clean['Annual Income'] <= upper_bound)]

print(f"After: {len(df_clean)}")
# Out:
# Before: 22080
# After: 21284

# %%
plt.figure(figsize=(8,8))
plt.boxplot(df_clean['Annual Income'])
ax = plt.gca()
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda num, p: f'{int(num):,}'))

# %% [markdown]
# ## Phase 4: Feature Engineering (Before Cleaning)

# %% [markdown]
# I have decided to get rid of the company column as it has 30 unique values.
#
# I will replace it with:

# %% [markdown]
# 1-A country of origin column
# ex:
#        'Toyota': 'Japanese',
#         'Honda': 'Japanese',
#          'Nissan': 'Japanese'

# %% [markdown]
# 2-Make another column to indicate:
# Luxury/ Mid-range / Economy

# %%
df['Company'].value_counts()
# Out:
# Company
# Chevrolet     1819
# Dodge         1670
# Ford          1614
# Volkswagen    1333
# Mercedes-B    1285
# Mitsubishi    1277
# Chrysler      1120
# Oldsmobile    1111
# Toyota        1110
# Nissan         886
# Mercury        874
# Lexus          802
# Pontiac        796
# BMW            790
# Volvo          789
# Honda          708
# Acura          689
# Cadillac       652
# Plymouth       617
# Saturn         586
# Lincoln        492
# Audi           468
# Buick          439
# Subaru         405
# Jeep           363
# Porsche        361
# Hyundai        264
# Saab           210
# Infiniti       195
# Jaguar         180
# Name: count, dtype: int64

# %% [markdown]
# Note: Making the map

# %%
company_to_country = {
    # USA
    "Chevrolet": "USA",
    "Dodge": "USA",
    "Ford": "USA",
    "Chrysler": "USA",
    "Oldsmobile": "USA",
    "Mercury": "USA",
    "Pontiac": "USA",
    "Cadillac": "USA",
    "Plymouth": "USA",
    "Saturn": "USA",
    "Lincoln": "USA",
    "Buick": "USA",
    "Jeep": "USA",

    # Japan
    "Toyota": "Japan",
    "Nissan": "Japan",
    "Honda": "Japan",
    "Lexus": "Japan",
    "Mitsubishi": "Japan",
    "Acura": "Japan",
    "Subaru": "Japan",
    "Infiniti": "Japan",

    # Germany
    "Volkswagen": "Germany",
    "Mercedes-B": "Germany",
    "BMW": "Germany",
    "Audi": "Germany",
    "Porsche": "Germany",

    # Sweden
    "Volvo": "Sweden",
    "Saab": "Sweden",

    # South Korea
    "Hyundai": "South Korea",

    # United Kingdom
    "Jaguar": "UK"
}

# %%
company_to_segment = {
    # Luxury
    "Mercedes-B": "Luxury",
    "Lexus": "Luxury",
    "BMW": "Luxury",
    "Volvo": "Luxury",
    "Acura": "Luxury",
    "Cadillac": "Luxury",
    "Lincoln": "Luxury",
    "Audi": "Luxury",
    "Porsche": "Luxury",
    "Saab": "Luxury",
    "Infiniti": "Luxury",
    "Jaguar": "Luxury",

    # Midrange
    "Dodge": "Midrange",
    "Ford": "Midrange",
    "Volkswagen": "Midrange",
    "Chrysler": "Midrange",
    "Oldsmobile": "Midrange",
    "Mercury": "Midrange",
    "Buick": "Midrange",
    "Subaru": "Midrange",
    "Jeep": "Midrange",

    # Economy
    "Chevrolet": "Economy",
    "Mitsubishi": "Economy",
    "Toyota": "Economy",
    "Nissan": "Economy",
    "Pontiac": "Economy",
    "Honda": "Economy",
    "Plymouth": "Economy",
    "Saturn": "Economy",
    "Hyundai": "Economy"
}

# %% [markdown]
# #### Mapping

# %%
df_clean['Brand Segment'] = df_clean['Company'].map(company_to_segment)
df_clean['Brand Country'] = df_clean['Company'].map(company_to_country)

# %% [markdown]
# #### Visualization for some columns

# %%
value_brand = df_clean['Brand Segment'].value_counts()
plt.pie(value_brand,
        labels=value_brand.index,
        autopct='%.2f%%',
        explode=(0, 0, 0.05),
        colors=['#5DD9C1', '#E07A5F', '#7768AE'])
plt.title("Brand segment")
plt.show()

# %%
value_trans = df_clean['Transmission'].value_counts()
plt.pie(value_trans,
        labels=value_trans.index,
        autopct='%.2f',
        colors=['#3185FC', '#FE5F55'])
plt.title("Transmission")
# Out:
# Text(0.5, 1.0, 'Transmission')

# %%
df_clean['Brand Country'].value_counts().plot.barh(figsize=(10,8))
plt.xlabel('Number of cars')
plt.title("Brand Country Distribution")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
sales_by_month = df_clean.groupby(df_clean['Date'].dt.to_period('M')).size()
plt.figure(figsize=(12,6))
sales_by_month.plot(kind='line', marker='o')
plt.xlabel('Month')
plt.ylabel('Number of Sales')
plt.title('Monthly Sales Trend')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Phase 5: Feature Transformation

# %% [markdown]
# #### 1-Log transform (fix skewness)

# %% [markdown]
# ### Before:

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21284 entries, 0 to 23905
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         21284 non-null  object
#  1   Date           21284 non-null  datetime64[ns]
#  2   Customer Name  21284 non-null  object
#  3   Gender         21284 non-null  object
#  4   Annual Income  21284 non-null  int64
#  5   Dealer_Name    21284 non-null  object
#  6   Company        21284 non-null  object
#  7   Model          21284 non-null  object
#  8   Engine         21284 non-null  object
#  9   Transmission   21284 non-null  object
#  10  Color          21284 non-null  object
#  11  Price ($)      21284 non-null  int64
#  12  Dealer_No      21284 non-null  object
#  13  Body Style     21284 non-null  object
#  14  Phone          21284 non-null  string
#  15  Dealer_Region  21284 non-null  object
#  16  Brand Segment  21284 non-null  object
#  17  Brand Country  21284 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(14), string(1)
# memory usage: 3.1+ MB

# %%
df_clean.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Date'}>,
#         <Axes: title={'center': 'Annual Income'}>],
#        [<Axes: title={'center': 'Price ($)'}>, <Axes: >]], dtype=object)

# %% [markdown]
# #### Note: Price ($) and Annual Income will be used for the transformation

# %%
for col in ['Price ($)', 'Annual Income']:
    df_clean[col] = np.log1p(df_clean[col])

# %% [markdown]
# ### After:

# %%
df_clean.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Date'}>,
#         <Axes: title={'center': 'Annual Income'}>],
#        [<Axes: title={'center': 'Price ($)'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ## Phase 5.5: Saving The New CSV

# %% [markdown]
# #### This step is to save time in saving the model when loading in the data later on!

# %%
df_clean.to_csv('data/cleaned_car_data.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Phase 6: Train-Test Split

# %%
x = df_clean.drop('Price ($)', axis=1)
y = df_clean['Price ($)']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Phase 7: Encoding Categorical Variables

# %%
x_train.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region', 'Brand Segment',
#        'Brand Country'],
#       dtype='object')

# %%
for col in ['Model', 'Engine', 'Transmission', 'Color', 'Body Style', 'Dealer_Region', 'Brand Segment', 'Brand Country']:
    print("-----------------------")
    print(x_train[col].value_counts())
    print(f"{col} has {x_train[col].nunique()} categories")
# Out:
# -----------------------
# Model
# Silhouette       307
# Passat           289
# LS400            284
# Prizm            281
# Diamante         272
#                 ...
# Mirage            16
# RX300             15
# Alero             14
# Avalon            13
# Sebring Conv.     10
# Name: count, Length: 154, dtype: int64
# Model has 154 categories
# -----------------------
# Engine
# Double Overhead Camshaft    8950
# Overhead Camshaft           8077
# Name: count, dtype: int64
# Engine has 2 categories
# -----------------------
# Transmission
# Auto      8950
# Manual    8077
# Name: count, dtype: int64
# Transmission has 2 categories
# -----------------------
# Color
# Pale White    8040
# Black         5601
# Red           3386
# Name: count, dtype: int64
# Color has 3 categories
# -----------------------
# Body Style
# SUV          4527
# Hatchback    4316
# Sedan        3210
# Passenger    2844
# Hardtop      2130
# Name: count, dtype: int64
# Body Style has 5 categories
# -----------------------
# Dealer_Region
# Austin        2902
# Janesville    2709
# Scottsdale    2514
# Middletown    2252
# Greenville    2227
# Pasco         2226
# Aurora        2197
# Name: count, dtype: int64
# Dealer_Region has 7 categories
# -----------------------
# Brand Segment
# Midrange    6279
# Economy     5738
# Luxury      5010
# Name: count, dtype: int64
# Brand Segment has 3 categories
# -----------------------
# Brand Country
# USA            8597
# Japan          4354
# Germany        2998
# Sweden          749
# South Korea     190
# UK              139
# Name: count, dtype: int64
# Brand Country has 6 categories

# %% [markdown]
# #### Remake
# 1-Categories for LabelEncoder:
# -Engine
# -Transmission
# -Brand Segment
#
# 2-Categories for OneHotEncoder:
# -Color
# -Body Style
# -Brand Country
# -Dealer_Region
#
# 3-Category for TargetEncoder:
# -Model

# %% [markdown]
# #### Note: fit_transform for training data and do not forget transform for testing data

# %% [markdown]
# ### 1-Label encoder

# %%
label_enc = LabelEncoder()

x_train['Engine'] = label_enc.fit_transform(x_train['Engine'])
x_test['Engine'] = label_enc.transform(x_test['Engine'])

x_train['Transmission'] = label_enc.fit_transform(x_train['Transmission'])
x_test['Transmission'] = label_enc.transform(x_test['Transmission'])

x_train['Brand Segment'] = label_enc.fit_transform(x_train['Brand Segment'])
x_test['Brand Segment'] = label_enc.transform(x_test['Brand Segment'])

# %% [markdown]
# ### 2-One Hot encoder

# %%
hot_encoder = OneHotEncoder(sparse_output=False).set_output(transform='pandas') #to return a dataframe instead of a numpy array
encoded_color_train = hot_encoder.fit_transform(x_train[['Color']])
encoded_color_test = hot_encoder.transform(x_test[['Color']])

encoded_bodyStyle_train = hot_encoder.fit_transform(x_train[['Body Style']])
encoded_bodyStyle_test = hot_encoder.transform(x_test[['Body Style']])

encoded_brandCountry_train = hot_encoder.fit_transform(x_train[['Brand Country']])
encoded_brandCountry_test = hot_encoder.transform(x_test[['Brand Country']])


encoded_dealerRegion_train = hot_encoder.fit_transform(x_train[['Dealer_Region']])
encoded_dealerRegion_test = hot_encoder.transform(x_test[['Dealer_Region']])

# %%
x_train = x_train.drop(['Color', 'Body Style', 'Brand Country', 'Dealer_Region'], axis=1)
x_train = pd.concat([x_train, encoded_color_train, encoded_bodyStyle_train,
                     encoded_brandCountry_train, encoded_dealerRegion_train], axis=1)

x_test = x_test.drop(['Color', 'Body Style', 'Brand Country', 'Dealer_Region'], axis=1)
x_test = pd.concat([x_test, encoded_color_test, encoded_bodyStyle_test,
                    encoded_brandCountry_test, encoded_dealerRegion_test], axis=1)

# %%
df_clean['Model'].value_counts()
# Out:
# Model
# Passat           367
# Silhouette       367
# RL               353
# Ram Pickup       348
# Prizm            347
#                 ...
# Mirage            17
# Alero             17
# RX300             15
# Avalon            13
# Sebring Conv.     10
# Name: count, Length: 154, dtype: int64

# %% [markdown]
# ### 3-Target encoder

# %% [markdown]
# Since we have 154 individual models and the model will affect the price, using a one hot encoder will be a waste as it will create 154 columns which is... a lot!

# %% [markdown]
# So I found about target encoding.
# Target Encoding: replaces each category with a numerical value based on the target(what we will predict) mean value for that category.
# It is useful for really high cardinality features and capturing the relationship between each category and the target

# %% [markdown]
# Equation for the target encoder behind the scenes:
# $$
# EncodedValue_i = \frac{n_i \times Mean_i + k \times GlobalMean}{n_i + k}
# $$

# %% [markdown]
# n: number of rows for category i
# Mean: mean of target value for category i
# GlobalMean: mean target value for all categories combined (entire dataset)
# k: smoothing factor

# %% [markdown]
# Smoothing factor:
# controls how much to trust the global mean vs the category mean.
# Example:
#
# If we have car_model 'A' and car_model 'B' and car_model 'C', with number of rows: 300, 140, 10
# and with avg price: 20500, 18000, 50000 respectfully (global mean is 25000)
#
# since we don't have many values for car_model 'C' like car_model 'A' or 'B', the machine learning model will learn that car_model 'C' is expensive which may not be true (because we may not have sold many cars for that car_model for example) and that will cause **"Overfiting"** the model
#  In the future if we enter more car data (100 car for example) of that car_model and their price is between 20000-30000, the model will predict 50000 because it "learned" that 50000 is the true value for that car_model so it is wrong and confident
#
# With the smoothing factor, the car_model 'C' mean will be closer to the global mean (25000) so now these rare or small categories don't dominate the model's learning and the predictions are more realistic

# %% [markdown]
# Note:
# (k: smoothing factor)
# -A lot of rows per cat -> k (3-5)
# -Some cats have low rows -> k (5-15)
# -A lot of rare cats (low num of rows) like 100+ models -> (10-30)
# -Very small dataset overall -> k (20- 50)

# %%
target_enc = TargetEncoder(cols=['Model'], smoothing=30)

x_train['Model'] = target_enc.fit_transform(x_train['Model'], y_train)
x_test['Model'] = target_enc.transform(x_test['Model'])

# %% [markdown]
# ## Phase 8: Drop Unnecessary Columns

# %% [markdown]
# Note: Make a correlation heatmap to see if any columns have a good relationship to drop one of them

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17027 entries, 10510 to 17789
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Car_id                     17027 non-null  object
#  1   Date                       17027 non-null  datetime64[ns]
#  2   Customer Name              17027 non-null  object
#  3   Gender                     17027 non-null  object
#  4   Annual Income              17027 non-null  float64
#  5   Dealer_Name                17027 non-null  object
#  6   Company                    17027 non-null  object
#  7   Model                      17027 non-null  float64
#  8   Engine                     17027 non-null  int64
#  9   Transmission               17027 non-null  int64
#  10  Dealer_No                  17027 non-null  object
#  11  Phone                      17027 non-null  string
#  12  Brand Segment              17027 non-null  int64
#  13  Color_Black                17027 non-null  float64
#  14  Color_Pale White           17027 non-null  float64
#  15  Color_Red                  17027 non-null  float64
#  16  Body Style_Hardtop         17027 non-null  float64
#  17  Body Style_Hatchback       17027 non-null  float64
#  18  Body Style_Passenger       17027 non-null  float64
#  19  Body Style_SUV             17027 non-null  float64
#  20  Body Style_Sedan           17027 non-null  float64
#  21  Brand Country_Germany      17027 non-null  float64
#  22  Brand Country_Japan        17027 non-null  float64
#  23  Brand Country_South Korea  17027 non-null  float64
#  24  Brand Country_Sweden       17027 non-null  float64
#  25  Brand Country_UK           17027 non-null  float64
#  26  Brand Country_USA          17027 non-null  float64
#  27  Dealer_Region_Aurora       17027 non-null  float64
#  28  Dealer_Region_Austin       17027 non-null  float64
#  29  Dealer_Region_Greenville   17027 non-null  float64
#  30  Dealer_Region_Janesville   17027 non-null  float64
#  31  Dealer_Region_Middletown   17027 non-null  float64
#  32  Dealer_Region_Pasco        17027 non-null  float64
#  33  Dealer_Region_Scottsdale   17027 non-null  float64
# dtypes: datetime64[ns](1), float64(23), int64(3), object(6), string(1)
# memory usage: 4.5+ MB

# %%
columns = ['Annual Income', 'Model', 'Engine', 'Transmission', 'Brand Segment']

plt.figure(figsize=(7,7))
heatmap = sns.heatmap(x_train[columns].corr(),annot=True, cmap='coolwarm', fmt=".2f", )
heatmap.set_title("Car correlation map")
plt.show()

# %% [markdown]
# #### We can see that Transmission and Engine both have a good relationship (1)

# %%
x_train
# Out:
#              Car_id       Date Customer Name  Gender  Annual Income  \
# 10510  C_CND_010511 2022-12-27        Jasper  Female      13.543703
# 12549  C_CND_012550 2023-04-07     Charlotte    Male      14.294846
# 11249  C_CND_011250 2023-02-05       Vincent  Female      13.554147
# 5780   C_CND_005781 2022-09-17        Raizel    Male       9.510519
# 16502  C_CND_016503 2023-08-05        Fradel    Male      13.901689
# ...             ...        ...           ...     ...            ...
# 12655  C_CND_012656 2023-04-09        Mariam    Male      13.011434
# 13431  C_CND_013432 2023-05-06        Connor    Male      13.208543
# 6057   C_CND_006058 2022-09-21        Jadiel  Female      13.253393
# 972    C_CND_000973 2022-03-16     Abdoulaye    Male       9.510519
# 17789  C_CND_017790 2023-09-05         Ahnaf    Male      14.557448
#
#                                            Dealer_Name     Company      Model  \
# 10510                   Ryder Truck Rental and Leasing     Pontiac  10.474596
# 12549                           Chrysler of Tri-Cities        Jeep   9.794532
# 11249                  New Castle Ford Lincoln Mercury     Lincoln  10.069028
# 5780                                     Classic Chevy       Dodge  10.326181
# 16502                             Rabun Used Car Sales  Volkswagen   9.806400
# ...                                                ...         ...        ...
# 12655                              Hatfield Volkswagen        Jeep   9.794532
# 13431                              Hatfield Volkswagen   Chevrolet   9.894769
# 6057                              Star Enterprises Inc      Toyota  10.604202
# 972                  Scrivener Performance Engineering        Jeep  10.070393
# 17789  Progressive Shippers Cooperative Association No     Mercury  10.247522
#
#        Engine  Transmission  ... Brand Country_Sweden Brand Country_UK  \
# 10510       1             1  ...                  0.0              0.0
# 12549       0             0  ...                  0.0              0.0
# 11249       1             1  ...                  0.0              0.0
# 5780        0             0  ...                  0.0              0.0
# 16502       0             0  ...                  0.0              0.0
# ...       ...           ...  ...                  ...              ...
# 12655       0             0  ...                  0.0              0.0
# 13431       1             1  ...                  0.0              0.0
# 6057        1             1  ...                  0.0              0.0
# 972         0             0  ...                  0.0              0.0
# 17789       0             0  ...                  0.0              0.0
#
#        Brand Country_USA  Dealer_Region_Aurora  Dealer_Region_Austin  \
# 10510                1.0                   0.0                   0.0
# 12549                1.0                   0.0                   0.0
# 11249                1.0                   0.0                   1.0
# 5780                 1.0                   0.0                   0.0
# 16502                0.0                   0.0                   0.0
# ...                  ...                   ...                   ...
# 12655                1.0                   0.0                   0.0
# 13431                1.0                   0.0                   0.0
# 6057                 0.0                   0.0                   0.0
# 972                  1.0                   0.0                   0.0
# 17789                1.0                   0.0                   0.0
#
#        Dealer_Region_Greenville  Dealer_Region_Janesville  \
# 10510                       0.0                       0.0
# 12549                       0.0                       0.0
# 11249                       0.0                       0.0
# 5780                        0.0                       0.0
# 16502                       0.0                       0.0
# ...                         ...                       ...
# 12655                       0.0                       0.0
# 13431                       0.0                       0.0
# 6057                        0.0                       0.0
# 972                         0.0                       1.0
# 17789                       0.0                       1.0
#
#        Dealer_Region_Middletown  Dealer_Region_Pasco  Dealer_Region_Scottsdale
# 10510                       1.0                  0.0                       0.0
# 12549                       1.0                  0.0                       0.0
# 11249                       0.0                  0.0                       0.0
# 5780                        0.0                  0.0                       1.0
# 16502                       0.0                  0.0                       1.0
# ...                         ...                  ...                       ...
# 12655                       0.0                  1.0                       0.0
# 13431                       0.0                  1.0                       0.0
# 6057                        0.0                  1.0                       0.0
# 972                         0.0                  0.0                       0.0
# 17789                       0.0                  0.0                       0.0
#
# [17027 rows x 34 columns]

# %%
cols_to_drop = ['Car_id', 'Date', 'Customer Name', 'Dealer_Name', 'Company', 'Engine', 'Dealer_No ', 'Phone', 'Gender']

x_train.drop(columns=cols_to_drop, inplace=True)
x_test.drop(columns=cols_to_drop, inplace=True)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17027 entries, 10510 to 17789
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Annual Income              17027 non-null  float64
#  1   Model                      17027 non-null  float64
#  2   Transmission               17027 non-null  int64
#  3   Brand Segment              17027 non-null  int64
#  4   Color_Black                17027 non-null  float64
#  5   Color_Pale White           17027 non-null  float64
#  6   Color_Red                  17027 non-null  float64
#  7   Body Style_Hardtop         17027 non-null  float64
#  8   Body Style_Hatchback       17027 non-null  float64
#  9   Body Style_Passenger       17027 non-null  float64
#  10  Body Style_SUV             17027 non-null  float64
#  11  Body Style_Sedan           17027 non-null  float64
#  12  Brand Country_Germany      17027 non-null  float64
#  13  Brand Country_Japan        17027 non-null  float64
#  14  Brand Country_South Korea  17027 non-null  float64
#  15  Brand Country_Sweden       17027 non-null  float64
#  16  Brand Country_UK           17027 non-null  float64
#  17  Brand Country_USA          17027 non-null  float64
#  18  Dealer_Region_Aurora       17027 non-null  float64
#  19  Dealer_Region_Austin       17027 non-null  float64
#  20  Dealer_Region_Greenville   17027 non-null  float64
#  21  Dealer_Region_Janesville   17027 non-null  float64
#  22  Dealer_Region_Middletown   17027 non-null  float64
#  23  Dealer_Region_Pasco        17027 non-null  float64
#  24  Dealer_Region_Scottsdale   17027 non-null  float64
# dtypes: float64(23), int64(2)
# memory usage: 3.4 MB

# %% [markdown]
# ## Phase 9: Feature Scaling

# %%
scaler = StandardScaler()

x_train[['Annual Income']] = scaler.fit_transform(x_train[['Annual Income']])
x_test[['Annual Income']] = scaler.transform(x_test[['Annual Income']])

# %% [markdown]
# ## Phase 10: Final Validation

# %%
x_train.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
x_train.shape
# Out:
# (17027, 25)

# %%
x_train.duplicated().value_counts()
# Out:
# False    15226
# True      1801
# Name: count, dtype: int64

# %%
x_train = x_train.drop_duplicates()
y_train = y_train[x_train.index] #so i dont get a missmatch error cuz the number of rows was decreased in the x_train

# %%
x_train.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Phase 11: Final Visualization

# %% [markdown]
# ### Heatmap

# %%
plt.figure(figsize=(5,5))

heatmap = sns.heatmap(x_train[['Annual Income', 'Model', 'Brand Segment']].corr(),
                      annot=True,
                      cmap='coolwarm',
                      fmt=".2f", )

heatmap.set_title("Car correlation map")
# Out:
# Text(0.5, 1.0, 'Car correlation map')

# %%
x_train.hist(figsize=(15,15))
plt.show()

# %% [markdown]
# ## Phase 12: Picking a model

# %% [markdown]
# Since our target is to predict the price, I have chosen 6 model to work with and pick the top 2 best preforming

# %% [markdown]
# #### Importing the evaluation matrices that I will use for each model

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_percentage_error

# %% [markdown]
# ### Evaluation and training function

# %%
def evaluate_model(model_prediction) -> dict:

    model_r2 = r2_score(y_test, model_prediction)

    # reverse the log transformation for RMSE and MAPE so we can understand the results
    y_test_actual = np.expm1(y_test) #log1p = log(1 + x) || expm1 = (e^x) - 1
    pred_actual = np.expm1(model_prediction)

    rmse = np.sqrt(mean_squared_error(y_test_actual, pred_actual))
    mape = mean_absolute_percentage_error(y_test_actual, pred_actual)


    return {
        'R² (log)': model_r2,
        'RMSE ($)': rmse,
        'MAPE (%)': mape * 100
    }

# %% [markdown]
# ### 1- multiple linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
multi_reg_model = LinearRegression()
multi_reg_model.fit(x_train, y_train)
multi_predict = multi_reg_model.predict(x_test)

# %%
multi_reg_model.coef_
# Out:
# array([ 1.38479347e-03,  1.09404446e+00, -1.77205946e-02, -6.70596391e-03,
#         2.14377631e-02, -2.29994985e-02,  1.56173541e-03, -2.34410143e-03,
#         1.09782972e-02,  5.49094724e-04, -3.33698589e-04, -8.84959188e-03,
#         8.64451138e-03, -1.05803470e-02, -1.06987272e-02,  4.52574469e-03,
#         1.25352867e-02, -4.42646857e-03,  7.15250468e-03,  5.72687533e-03,
#         1.25550248e-02, -1.56757292e-02, -6.39664169e-03, -1.09960562e-02,
#         7.63402240e-03])

# %%
multi_reg_model.intercept_
# Out:
# np.float64(-0.932258254847282)

# %% [markdown]
# **Evaluate the model**

# %%
evaluate_model(multi_predict)
# Out:
# {'R² (log)': 0.23912568636032594,
#  'RMSE ($)': np.float64(12600.16211599561),
#  'MAPE (%)': 33.0593980737559}

# %%
from sklearn.model_selection import GridSearchCV

def run_grid(model_to_use, parameters_to_test, cv, score):
    grid = GridSearchCV(estimator=model_to_use, param_grid=parameters_to_test, cv= cv, scoring= score, n_jobs=-1)
    #n_jobs = -1 will make the program use all the cpu cores but will reduce waiting time

    grid.fit(x_train, y_train) #loops in the parameters_to_test and fits the data, the end product is the r2 score of the model
    return grid

# %% [markdown]
# ### 2-KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score

k_values = range(1, 31)
scores = []

for k in k_values:
    model = KNeighborsRegressor(n_neighbors=k)
    cv_score = cross_val_score(model, x_train, y_train, cv=5, scoring='r2')
    scores.append(cv_score.mean())

best_k = k_values[np.argmax(scores)]
print("Best k:", best_k)
# Out:
# Best k: 6

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, scores, 'bo-', linewidth=2, markersize=8)
plt.axvline(x=best_k, color='r', linestyle='-', label=f'Best k = {best_k}')
plt.xlabel('Number of Neighbors (k)', fontsize=12)
plt.ylabel('Cross-Validation R² Score', fontsize=12)
plt.title('Elbow Curve: K-NN Model Performance', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
knn_model = KNeighborsRegressor(n_neighbors=6)
knn_model.fit(x_train, y_train)
knn_predict = knn_model.predict(x_test)

# %%
evaluate_model(knn_predict)
# Out:
# {'R² (log)': 0.30069844649960376,
#  'RMSE ($)': np.float64(12027.315321848513),
#  'MAPE (%)': 30.364458722713856}

# %% [markdown]
# ### 3-Decision tree

# %%
from sklearn.tree import DecisionTreeRegressor

depths = range(1, 21)
scores = []

for d in depths:
    model = DecisionTreeRegressor(max_depth=d, random_state=42)
    cv_score = cross_val_score(model, x_train, y_train, cv=5, scoring='r2')
    scores.append(cv_score.mean())

best_depth = depths[np.argmax(scores)]
print("Best max_depth:", best_depth)
# Out:
# Best max_depth: 11

# %%
plt.figure(figsize=(10,6))
plt.plot(depths, scores, 'bo-', linewidth=2, markersize=8)
plt.axvline(x=best_depth, color='r', linestyle='-', label=f'Best depth = {best_depth}')
plt.xlabel('Max Depth')
plt.ylabel('Cross validated R² score')
plt.title('Choosing max_depth for Decision Tree')
plt.legend()
plt.show()

# %%
decision_tree_model = DecisionTreeRegressor(max_depth=11)
decision_tree_model.fit(x_train, y_train)
tree_predict = decision_tree_model.predict(x_test)

# %%
evaluate_model(tree_predict)
# Out:
# {'R² (log)': 0.6734174445521928,
#  'RMSE ($)': np.float64(8159.4397775458265),
#  'MAPE (%)': 16.66713674504044}

# %% [markdown]
# ### 4-Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

param_grid = {
    'n_estimators': [100, 200, 300, 500],
    'max_depth': [9, 11, None],
    'min_samples_split': [10, 15, 20]
}

rf = RandomForestRegressor(random_state=42)
after_grid = run_grid(rf, param_grid, 5, 'r2')

print(after_grid.best_params_)
print(after_grid.best_score_)

# %%
rf_model = RandomForestRegressor(n_estimators=500, max_depth=None, min_samples_split=15)
rf_model.fit(x_train, y_train)
rf_predict = rf_model.predict(x_test)

# %%
evaluate_model(rf_predict)
# Out:
# {'R² (log)': 0.7390694566062264,
#  'RMSE ($)': np.float64(7287.4866000954635),
#  'MAPE (%)': 15.200140789138969}

# %% [markdown]
# ### 5-XGBOOST

# %%
from xgboost import XGBRegressor
params = {
    'n_estimators': [400, 500],
    'max_depth': [9, 11, None],
    'learning_rate': [0.01, 0.1, 0.5],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9]
}

xgb = XGBRegressor()

after_grid = run_grid(xgb, params, 5, 'r2')
after_grid.fit(x_train, y_train)

print(after_grid.best_params_)
print(after_grid.best_score_)

# %% [markdown]
# {'colsample_bytree': 0.9, 'learning_rate': 0.01, 'max_depth': 11, 'n_estimators': 400, 'subsample': 0.9}
# 0.7003515810264925
#
# 10.45m

# %%
from xgboost import XGBRegressor

xgb_model = XGBRegressor(
    n_estimators=400,
    max_depth=9,
    subsample=0.9,
    colsample_bytree=0.9,
    learning_rate=0.01,
    tree_method='hist',
    device='cuda'
)

xgb_model.fit(x_train, y_train)
xgb_predict = xgb_model.predict(x_test)

# %%
evaluate_model(xgb_predict)
# Out:
# {'R² (log)': 0.7157409105888635,
#  'RMSE ($)': np.float64(7758.989412475865),
#  'MAPE (%)': 18.097929915092852}

# %% [markdown]
# ### 6-SVM

# %%
from sklearn.svm import SVR

param_grid = {
    'C': [15, 20, 30],
    'epsilon': [0.1, 0.5, 1],
    'gamma': ['auto', 0.01, 0.05],
    'kernel': ['rbf']
}

svr = SVR()

after_grid = run_grid(svr, param_grid, 5, 'r2')
after_grid.fit(x_train, y_train)

# Best parameters
print("Best parameters:", after_grid.best_params_)
print("Best CV score:", after_grid.best_score_)

# %%
svr_model = SVR(kernel='rbf', gamma=0.05, C= 30, epsilon=0.1)
svr_model.fit(x_train, y_train)
svr_predict = svr_model.predict(x_test)
evaluate_model(svr_predict)
# Out:
# {'R² (log)': 0.3460620500618077,
#  'RMSE ($)': np.float64(11593.44934111688),
#  'MAPE (%)': 28.724306676848}

# %% [markdown]
# ### Now picking the top 2 best performing models

# %% [markdown]
# #### Random forest and XGboost

# %% [markdown]
# **Random forest**
# {'R² (log)': 0.7388642739640111,
#  'RMSE ($)': np.float64(7288.628227089223),
#  'MAPE (%)': 15.201767088177487}

# %% [markdown]
# **XGboost**
# {'R² (log)': 0.7150250786795239,
#  'RMSE ($)': np.float64(7770.033769863793),
#  'MAPE (%)': 18.109599771419116}

# %% [markdown]
# Random forest || XGboost
# r2: rf higher by (2.3%) >
# rmse: rf lower by (500$)  >
# mape: rf lower by (3%) >

# %% [markdown]
# ## Phase 13: Improving the models

# %% [markdown]
# #### In order to improve the model, we can use "feature selection" which will select the features with more influence to the model predictions and ditching the less important ones.

# %% [markdown]
# #### Features we have as of now:

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15226 entries, 10510 to 17789
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Annual Income              15226 non-null  float64
#  1   Model                      15226 non-null  float64
#  2   Transmission               15226 non-null  int64
#  3   Brand Segment              15226 non-null  int64
#  4   Color_Black                15226 non-null  float64
#  5   Color_Pale White           15226 non-null  float64
#  6   Color_Red                  15226 non-null  float64
#  7   Body Style_Hardtop         15226 non-null  float64
#  8   Body Style_Hatchback       15226 non-null  float64
#  9   Body Style_Passenger       15226 non-null  float64
#  10  Body Style_SUV             15226 non-null  float64
#  11  Body Style_Sedan           15226 non-null  float64
#  12  Brand Country_Germany      15226 non-null  float64
#  13  Brand Country_Japan        15226 non-null  float64
#  14  Brand Country_South Korea  15226 non-null  float64
#  15  Brand Country_Sweden       15226 non-null  float64
#  16  Brand Country_UK           15226 non-null  float64
#  17  Brand Country_USA          15226 non-null  float64
#  18  Dealer_Region_Aurora       15226 non-null  float64
#  19  Dealer_Region_Austin       15226 non-null  float64
#  20  Dealer_Region_Greenville   15226 non-null  float64
#  21  Dealer_Region_Janesville   15226 non-null  float64
#  22  Dealer_Region_Middletown   15226 non-null  float64
#  23  Dealer_Region_Pasco        15226 non-null  float64
#  24  Dealer_Region_Scottsdale   15226 non-null  float64
# dtypes: float64(23), int64(2)
# memory usage: 3.0 MB

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
#Forward selection function
def run_sfs(model_to_use):
    sfs = SFS(model_to_use,
              k_features='best',
              forward=True,
              floating=False, #allow features that were previously added (in forward) or removed (in backward) to be reconsidered at later steps.
              scoring='r2',
              cv=5,
              n_jobs=-1)

    sfs = sfs.fit(x_train, y_train)
    selected_features = list(sfs.k_feature_names_)

    return selected_features

# %% [markdown]
# I will try "forward" selection only due to computational limitation, and you can try recursive feature elimination (rfe) which is better (but I wont)

# %% [markdown]
# RFE:
#     A combination of backward elimination with a recursive approach.
#     Ranks all the features based on their importance.
#     Recursively removes the least important ones and retrains the model.
#     Continues until the desired number of features is reached.

# %% [markdown]
# ### 1-Random forest

# %%
selected_features = run_sfs(rf_model)
X_train_sfs = x_train[selected_features]
X_test_sfs = x_test[selected_features]

# %%
selected_features
# Out:
# ['Model',
#  'Transmission',
#  'Brand Segment',
#  'Color_Black',
#  'Color_Pale White',
#  'Color_Red',
#  'Body Style_Sedan',
#  'Brand Country_Germany',
#  'Brand Country_Japan',
#  'Brand Country_USA']

# %% [markdown]
# run_sfs(rf_model) took me 17 minute to compute, and this is the features it decided to choose:

# %% [markdown]
# ['Model',
#  'Transmission',
#  'Brand Segment',
#  'Color_Black',
#  'Color_Pale White',
#  'Color_Red',
#  'Body Style_Sedan',
#  'Brand Country_Germany',
#  'Brand Country_Japan',
#  'Brand Country_USA']

# %%
rf_model_final = RandomForestRegressor(n_estimators=500, max_depth=None, min_samples_split=15)
rf_model_final.fit(X_train_sfs, y_train)
rf_predict_final = rf_model_final.predict(X_test_sfs)

# %%
evaluate_model(rf_predict_final)
# Out:
# {'R² (log)': 0.7547457321644195,
#  'RMSE ($)': np.float64(7060.693260738497),
#  'MAPE (%)': 14.01944951273863}

# %% [markdown]
# **BEFORE**
# {'R² (log)': 0.7388642739640111,
#  'RMSE ($)': np.float64(7288.628227089223),
#  'MAPE (%)': 15.201767088177487}

# %% [markdown]
# **AFTER**
# {'R² (log)': 0.7547457321644195,
#  'RMSE ($)': np.float64(7060.693260738497),
#  'MAPE (%)': 14.01944951273863}

# %% [markdown]
# ### 2-XGBoost

# %%
# xgb_sfs = run_sfs(xgb_model)

# %%
selected_features = ['Model', 'Transmission', 'Brand Segment', 'Color_Black', 'Color_Pale White', 'Color_Red', 'Body Style_Sedan', 'Brand Country_Germany', 'Brand Country_Japan', 'Brand Country_USA']
#I ran xgb_sfs on Google colab, and it took me 40 minutes... so I just copied the output
X_train_sfs_xgb = x_train[selected_features]
X_test_sfs_xgb = x_test[selected_features]

# %% [markdown]
#  output of run_sfs(xgb_model):
#  'Selected features: ['Model', 'Transmission', 'Brand Segment', 'Color_Black', 'Color_Pale White', 'Color_Red', 'Body Style_Sedan', 'Brand Country_Germany', 'Brand Country_Japan', 'Brand Country_USA']'

# %%
xgb_model_final = XGBRegressor(
    n_estimators=400,
    max_depth=9,
    subsample=0.9,
    colsample_bytree=0.9,
    learning_rate=0.01,
    tree_method='hist',
    device='cuda')

xgb_model_final.fit(X_train_sfs, y_train)
xgb_predict_final = xgb_model_final.predict(X_test_sfs)

# %%
evaluate_model(xgb_predict_final)
# Out:
# {'R² (log)': 0.7341065648170572,
#  'RMSE ($)': np.float64(7466.225991441026),
#  'MAPE (%)': 16.954583651012904}

# %% [markdown]
# **BEFORE**
# {'R² (log)': 0.7157409105888635,
#  'RMSE ($)': np.float64(7758.989412475865),
#  'MAPE (%)': 18.097929915092852}

# %% [markdown]
# **AFTER**
# {'R² (log)': 0.7341065648170572,
#  'RMSE ($)': np.float64(7466.225991441026),
#  'MAPE (%)': 16.954583651012904}

# %% [markdown]
# ## Final Phase: Saving the model

# %% [markdown]
# After seeing the results and comparing them, the model that "won" is Random forest.

# %% [markdown]
# Please check app.ipynb for saving the model!
